# %% [markdown]
# # 和python相关的必要工具推荐
#
# 1. 搜索工具 [**Google**](https://www.google.com), [Bing](https://www.bing.com)
# 2. Windows下的工具 终端[**cmder**](http://cmder.net/), [powershell](https://github.com/PowerShell/PowerShell), 编译器套件[**Mingw** and **GCC**](http://www.mingw.org/), [GFortran](https://gcc.gnu.org/wiki/GFortranBinaries#Windows), [VS套件](https://www.visualstudio.com/zh-hans/)
# 3. 爬墙梯子 [Lantern](https://github.com/getlantern/lantern/releases/tag/latest), [Shadowsocks](https://github.com/shadowsocks/shadowsocks/wiki)
# 4. python包管理 [**Anaconda**](http://www.continuum.io/downloads)
# 5. IDE [**pycharm**](https://www.jetbrains.com/pycharm/), [Spyder](https://pythonhosted.org/spyder/)(Anaconda内置)
# 6. 编辑器 [**Atom**](https://atom.io/), [Sublime](https://www.sublimetext.com/), [VS Code](https://code.visualstudio.com/)
# 7. 代码版本管理 [**git**](http://www.liaoxuefeng.com/wiki/0013739516305929606dd18361248578c67b8067c8c017b000)
# 8. 教程 [基本入门](http://www.liaoxuefeng.com/wiki/0014316089557264a6b348958f449949df42a6d3a2e542c000), [科学计算和可视化](https://github.com/lijin-THU/notes-python)
# 9. 其他 [stackoverflow](https://stackoverflow.com/)

# %% [markdown]
# ## 1. Anaconda安装
#
# 以MAC OSX 为例：
#
# 1.Graphical Installer
#
# Download the graphical installer
# Double-click the downloaded .pkg file and follow the instructions
#
# 2.Command Line Installer
#
# Download the command-line installer
# Optional: Verify data integrity with MD5 or SHA-256   More info
# In your terminal window type one of the below and follow the instructions:
# Python 3.6 version
# ```bash
# bash Anaconda3-4.3.1-MacOSX-x86_64.sh
# ```
# Python 2.7 version
# ```bash
# bash Anaconda2-4.3.1-MacOSX-x86_64.sh
# ```
# NOTE: Include the "bash" command even if you are not using the bash shell.
#
# 根据自己的操作系统安装好[Anaconda](http://www.continuum.io/downloads)后，在命令行下输入：
#
#     conda list
#
# 可以看已经安装好的**python**第三方工具包，这里我们使用 `magic` 命令 `%%cmd` 在 `ipython cell` 中来执行这个命令：

# %%
# !conda list
# Out:
# # packages in environment at /Users/hhuang/Anaconda:
# #
# acoustics                 0.1.2                     <pip>
# alabaster                 0.7.10                   py36_0    https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free
# anaconda                  custom                   py36_0    https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free
# anaconda-client           1.6.2                    py36_0    https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free
# appnope                   0.1.0                    py36_0    https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free
# arm_pyart                 1.9.0                     <pip>
# ARTview                   1.3.5                     <pip>
# autopep8                  1.2.4                    py36_2    conda-forge
# babel                     2.4.0                    py36_0    https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free
# ...

# %% [markdown]
# 第一次安装好 [Anaconda](http://www.continuum.io/downloads) 以后，可以在命令行输入以下命令使 [Anaconda](http://www.continuum.io/downloads) 保持最新：
#
#     conda update conda
#     conda update anaconda
# 在国内没有梯子情况下，下载更新会很慢，建议添加[清华的Anaconda 镜像](https://mirror.tuna.tsinghua.edu.cn/help/anaconda/)
#
# conda 是一种很强大的工具，具体用法可以参照它的[文档](http://conda.pydata.org/docs/)。
#
# 也可以参考它的 [cheat sheet](http://conda.pydata.org/docs/_downloads/conda-cheatsheet.pdf) 来快速查看它的用法。
#
# 可以使用它来安装，更新，卸载第三方的 **python** 工具包：
#
#     conda install <some package>
#     conda update <some package>
#     conda remove <some package>
#
# 在安装或更新时可以指定安装的版本号，例如需要使用 `numpy 1.8.1`：
#
#     conda install numpy=1.8.1
#     conda update numpy=1.8.1
#
# 查看 `conda` 的信息：
#
#     conda info

# %%
# !conda info
# Out:
# Current conda install:
#
#                platform : osx-64
#           conda version : 4.3.16
#        conda is private : False
#       conda-env version : 4.3.16
#     conda-build version : not installed
#          python version : 3.6.1.final.0
#        requests version : 2.13.0
#        root environment : /Users/hhuang/Anaconda  (writable)
#     default environment : /Users/hhuang/Anaconda
#        envs directories : /Users/hhuang/Anaconda/envs
#                           /Users/hhuang/.conda/envs
#           package cache : /Users/hhuang/Anaconda/pkgs
#                           /Users/hhuang/.conda/pkgs
#            channel URLs : https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free/osx-64
#                           https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free/noarch
#                           https://repo.continuum.io/pkgs/free/osx-64
#                           https://repo.continuum.io/pkgs/free/noarch
# ...

# %% [markdown]
# 一个很棒的功能是 `conda` 可以产生一个自定义的环境，假设在安装的是 **Python 3.6** 的情况下，想使用 **Python 2.7**，只需要在命令行下使用 `conda` 产生一个新的环境：
#
#     conda create -n py2k7 python=2.7
#
# 这里这个环境被命名为 `py2k7` ，可以根据喜好将 `py2k7` 改成其他的名字。
#
# 使用这个环境时，只需要命令行下输入：
#
# ``` python
# activate py2k7 #(windows)
# source activate py2k7 #(linux, mac)
# ```
#
# 此时，我们的 **Python** 版本便是 **`python 2.7`**了。

# %% [markdown]
# ### 启动spyder
#
# `Anaconda` 默认使用的编辑器是 [Spyder](http://code.google.com/p/spyderlib/)，可以在命令行下输入：
#
#     spyder
#
# 来进入这个编辑器，它是一个类似于MATLAB的IDE。它在环境中包含了源码编辑、执行、调试等全功能。
#
# 具体使用方法不做介绍。
#  is a MATLAB-like IDE for scientific computing with python. It has the many advantages of a traditional IDE environment, for example that everything from code editing, execution and debugging is carried out in a single environment, and work on different calculations can be organized as projects in the IDE environment.
#
# <img src="./figures/spyder-screenshot.jpg" width="800">
#
# Spyder的一些优点：
#
# * 简单、代码高亮、调试
# * 变量查看，IPython命令
# * 包含了文档和帮助文件

# %% [markdown]
# ## 2. Atom安装
#
# 要利用Atom进行Python开发，首先要安装Atom. 安装Atom事实上十分简单，只需要到[Atom官网](https://atom.io)，点击下载按钮，下载对应平台的安装包。
# <img src="./figures/fig1_Atom.png" alt="Drawing" style="height: 500px;"/>
#
# 当你第一次打开Atom，它会尝试安装命令行工具atom和apm，可能需要输入管理员密码。你也可以手动安装这些工具，如下图的Install Shell Commands：
# <img src="./figures/fig2_SC.png" alt="Drawing" style="height: 500px;"/>
#
# 安装完成后你可以打开命令行窗口直接输入`atom`命令打开Atom，同时可以使用apm进行包管理。如果你在防火墙后，可以使用
#
#     apm config set https-proxy YOUR_PROXY_ADDRESS
#
# 命令设置代理。

# %% [markdown]
# ### 2.1 Atom的设置和包安装
#
# <img src="./figures/fig3_setup.png" alt="Drawing" style="height: 500px;"/>
# 打开系统的偏好或者设置根据你的喜好进行设置。
#
# 安装Atom插件包的方法1.上图中有Install、Packages和Updates可以分别进行包的安装、管理、和升级工具；方法2. 利用apm工具进行，如：
#
#     apm update
#     apm install ****

# %%
! apm help
# Out:
# apm - Atom Package Manager powered by https://atom.io
#
# Usage: apm <command>
#
# where <command> is one of:
#     clean, config, dedupe, deinstall, delete, dev, develop, disable, docs,
#     enable, erase, featured, home, i, init, install, link, linked, links, list,
#     ln, lns, login, ls, open, outdated, publish, rebuild, rebuild-module-cache,
#     remove, rm, search, show, star, starred, stars, test, uninstall, unlink,
#     unpublish, unstar, update, upgrade, view.
#
# Run `apm help <command>` to see the more details about a specific command.
#
# Options:
#   --color        Enable colored output                                     [boolean] [default: true]
#   -v, --version  Print the apm version
#   -h, --help     Print this usage message
#
#   Prefix an option with `no-` to set it to false such as --no-color to disable
#   colored output.

# %%
! apm install -help
# Out:
# Usage: apm install [<package_name>...]
#        apm install <package_name>@<package_version>
#        apm install <git_remote>
#        apm install <github_username>/<github_project>
#        apm install --packages-file my-packages.txt
#        apm i (with any of the previous argument usage)
#
# Install the given Atom package to ~/.atom/packages/<package_name>.
#
# If no package name is given then all the dependencies in the package.json
# file are installed to the node_modules folder in the current working
# directory.
#
# A packages file can be specified that is a newline separated list of
# package names to install with optional versions using the
# `package-name@version` syntax.
#
# Options:
#   --check           Check that native build tools are installed                            [boolean]
#   --verbose         Show verbose debug information                        [boolean] [default: false]
# ...

# %% [markdown]
# ### 2.1 Atom开发python的常用包推荐
#
# 1. 自动补全工具 [autocomplete-python](https://atom.io/packages/autocomplete-python)
# 2. python语言支持 [language-python](https://atom.io/packages/language-python)
# 3. 常用工具 [python-tools](https://atom.io/packages/python-tools)
# 4. Atom运行代码 [script](https://atom.io/packages/script)
# 5. 代码规范检查工具 [linter-pycodestyle](https://atom.io/packages/linter-pycodestyle)
# 6. 代码自动规范 [atom-beautify](https://atom.io/packages/atom-beautify)
#
# 可根据需求安装
